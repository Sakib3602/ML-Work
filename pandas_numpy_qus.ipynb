# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakib3602/Numpy-Pandas/blob/main/pandas_numpy_qus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

np.random.seed(42)

ids = np.arange(1, 11)
ages = np.random.randint(18, 60, 10)
salaries = np.random.randint(30000, 90000, 10)
departments = np.array(["HR", "IT", "Finance", "IT", "HR", "Sales", "Finance", "IT", "Sales", "HR"])

DF = pd.DataFrame({
"id": ids,
"age": ages,
"salary": salaries,
"dept": departments
})

DF.to_csv("employees.csv", index=False)
print("Sample Data Created and Saved as employees.csv")
# Out:
# Sample Data Created and Saved as employees.csv

# %% [markdown]
# Q1. Create NumPy arrays from the ages and salaries data generated above. Print both arrays and display their dtype, ndim, shape, and size.

# %%
a = np.array(ages)
b = np.array(salaries)
print(a)
print(a.dtype)
print(a.ndim)
print(a.shape)
print(a.size)
print(b)
print(b.dtype)
print(b.ndim)
print(b.shape)
print(b.size)
# Out:
# [56 46 32 25 38 56 36 40 28 28]
# int64
# 1
# (10,)
# 10
# [77191 74131 46023 71090 31685 30769 89735 86101 32433 35311]
# int64
# 1
# (10,)
# 10

# %% [markdown]
# Q2. Using the salaries array, find and print the highest and lowest salary values. Also, calculate and print the average salary and age using NumPy functions.

# %%
c = b.max()
c1 = b.min()
print(f"Highest : {c} and Lowest : {c1}")

avg = b.sum() / b.size
print(f"Average : {avg}")
# Out:
# Highest : 89735 and Lowest : 30769
# Average : 57446.9

# %% [markdown]
# Q3. From the ages array, filter and print all ages greater than 30 using a boolean condition. Then count and print how many employees are older than 30.

# %%
age_filter = a > 30
m = a[age_filter]
print(f"Older then 30 is {m}")
print(len(m))
# Out:
# Older then 30 is [56 46 32 38 56 36 40]
# 7

# %% [markdown]
# Q4. Create a new NumPy array that increases every employee’s age by 5 years (without modifying the original array). Print the new updated ages array.

# %%
print(f"First a : {a}")
k = a + 5
print(f"Updated K {k}")
print(f"Not Changed {a}")
# Out:
# First a : [56 46 32 25 38 56 36 40 28 28]
# Updated K [61 51 37 30 43 61 41 45 33 33]
# Not Changed [56 46 32 25 38 56 36 40 28 28]

# %% [markdown]
# Q5. Using NumPy, calculate the total salary expense (sum of all salaries) and the difference between the maximum and minimum salary. Print both results.

# %%
total_sal = salaries.sum()
print(f"Total Salary : {total_sal}")

diff = salaries.max() - salaries.min()
print(f"DIFFERENCE BETWEEN MAX & MIN : {diff}")
# Out:
# Total Salary : 574469
# DIFFERENCE BETWEEN MAX & MIN : 58966

# %% [markdown]
# # **Pandas Qus**

# %% [markdown]
# Q6.Load the employees.csv file into a Pandas DataFrame. Display the first 5 rows, and check basic info using info() and summary statistics using describe().

# %%
cv = pd.read_csv("employees.csv")
c = pd.DataFrame(cv)
c1 = pd.DataFrame(cv)
print(c.head())
print("-------INFO---------")
c.info()
print("-------DESCRIBE---------")
c.describe()
# Out:
#    id  age  salary     dept
# 0   1   56   77191       HR
# 1   2   46   74131       IT
# 2   3   32   46023  Finance
# 3   4   25   71090       IT
# 4   5   38   31685       HR
# -------INFO---------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      10 non-null     int64
#  1   age     10 non-null     int64
#  2   salary  10 non-null     int64
#  3   dept    10 non-null     object
# dtypes: int64(3), object(1)
# memory usage: 452.0+ bytes
# -------DESCRIBE---------
#              id       age        salary
# count  10.00000  10.00000     10.000000
# mean    5.50000  38.50000  57446.900000
# std     3.02765  11.16791  24357.262884
# min     1.00000  25.00000  30769.000000
# 25%     3.25000  29.00000  33152.500000
# 50%     5.50000  37.00000  58556.500000
# 75%     7.75000  44.50000  76426.000000
# max    10.00000  56.00000  89735.000000

# %% [markdown]
# Q7. Display only the id, age, and salary columns. Then show the last 3 rows using tail().

# %%
p = c[['id','age','salary']]
p.tail(3)
# Out:
#    id  age  salary
# 7   8   40   86101
# 8   9   28   32433
# 9  10   28   35311

# %% [markdown]
# Q8. Filter the DataFrame to show only employees who work in the IT department. Print the result and show the total number of IT employees.

# %%
it = c[c["dept"] == "IT"]
print(it)
print(len(it))
# Out:
#    id  age  salary dept
# 1   2   46   74131   IT
# 3   4   25   71090   IT
# 7   8   40   86101   IT
# 3

# %% [markdown]
# Q9. Sort the DataFrame by salary in descending order and display the top 3 highest-paid employees along with their department and age.

# %%
c.sort_values("salary", ascending=False).head(3)
# Out:
#       id    age  salary   dept
# 6  80000  80000   80000  80000
# 7  80000  80000   80000  80000
# 0      1     56   77191     HR

# %% [markdown]
# Q10. Replace all salary values greater than 80000 with 80000 using loc. Then calculate and print the new average salary of all employees after replacement.

# %%
# c.loc[c["salary"] > 80000, "salary"] = 80000
c1.loc[c1["salary"] > 80000, "salary"] = 80000
print(c1)
op = len(c1["salary"])
sum = c1["salary"].sum()
avg = sum / op
print(f"AVG SALARY : {avg}")
# Out:
#    id  age  salary     dept
# 0   1   56   77191       HR
# 1   2   46   74131       IT
# 2   3   32   46023  Finance
# 3   4   25   71090       IT
# 4   5   38   31685       HR
# 5   6   56   30769    Sales
# 6   7   36   80000  Finance
# 7   8   40   80000       IT
# 8   9   28   32433    Sales
# 9  10   28   35311       HR
# AVG SALARY : 55863.3
