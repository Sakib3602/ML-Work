# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakib3602/Numpy-Pandas/blob/main/panda_1st.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("student_data (1).csv")
df = pd.read_excel("phitron_student_marks.xlsx")


# df.loc[0]b=B

# %%
# df.head()
df.tail()
# Out:
#    StudentID      FullName  Data Structure Marks  Algorithm Marks  \
# 15    PH1016  Ziaur Rahman                  94.0             94.0
# 16    PH1017   Afsana Mimi                  90.0             90.0
# 17    PH1018   Babul Ahmed                  88.0             88.0
# 18    PH1019  Faria Rahman                   NaN              NaN
# 19    PH1020    Nasir Khan                  86.0             86.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 15           NaN      In Progress     2024-08-21  Ms. Salma  Chattogram
# 16          93.0        Completed     2025-09-01  Mr. Karim       Dhaka
# 17          85.0        Completed     2025-09-05  Ms. Salma      Sylhet
# 18           NaN      Not Started     2025-09-15  Mr. David  Chattogram
# 19          89.0        Completed     2025-10-02  Ms. Salma       Dhaka

# %%
df.columns
cols = list(df.columns)
cols
# Out:
# ['StudentID',
#  'FullName',
#  'Data Structure Marks',
#  'Algorithm Marks',
#  'Python Marks',
#  'CompletionStatus',
#  'EnrollmentDate',
#  'Instructor',
#  'Location']

# %%
df.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   StudentID             20 non-null     object
#  1   FullName              20 non-null     object
#  2   Data Structure Marks  16 non-null     float64
#  3   Algorithm Marks       16 non-null     float64
#  4   Python Marks          15 non-null     float64
#  5   CompletionStatus      20 non-null     object
#  6   EnrollmentDate        20 non-null     object
#  7   Instructor            20 non-null     object
#  8   Location              20 non-null     object
# dtypes: float64(3), object(6)
# memory usage: 1.5+ KB

# %%
df.sample(10)
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 18    PH1019      Faria Rahman                   NaN              NaN
# 8     PH1009        Omar Faruq                  72.0             72.0
# 0     PH1001       Alif Rahman                  85.0             85.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 3           82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# ...

# %%
df.describe()
# Out:
#        Data Structure Marks  Algorithm Marks  Python Marks
# count             16.000000        16.000000     15.000000
# mean              84.000000        84.000000     85.666667
# std                6.501282         6.501282      5.394000
# min               72.000000        72.000000     76.000000
# 25%               79.500000        79.500000     83.000000
# 50%               85.500000        85.500000     85.000000
# 75%               88.250000        88.250000     88.500000
# max               94.000000        94.000000     95.000000

# %%
a = [["SAKIB" , 10],["AYON" , 20],["SAZU",30]]

x = pd.DataFrame(a,columns=["Name","Age"],index=["a","b","c"])
print(x)
print(type(x))
# Out:
#     Name  Age
# a  SAKIB   10
# b   AYON   20
# c   SAZU   30
# <class 'pandas.core.frame.DataFrame'>

# %%
tup = (("s",1),("l",4))

t = pd.DataFrame(tup)
print(t)
# Out:
#    0  1
# 0  s  1
# 1  l  4

# %%
dic = {
    "Name" : ["S","D","X"],
    "Age" : (10,20,30)
}

l = pd.DataFrame(dic)
print(l)
# Out:
#   Name  Age
# 0    S   10
# 1    D   20
# 2    X   30

# %%
df.loc[3,["FullName","Data Structure Marks"]]
# Out:
# FullName                Jannatul Ferdous
# Data Structure Marks                78.0
# Name: 3, dtype: object

# %%
df.loc[[2,6,9,0],["FullName","Data Structure Marks"]]
# Out:
#          FullName  Data Structure Marks
# 2   Imran Hossain                  88.0
# 6  Mahmudul Hasan                  80.0
# 9    Priya Sharma                  89.0
# 0     Alif Rahman                  85.0

# %%
# iloc use korle index jmn e hok numerical value diye access kora jay.

df.iloc[:,[1,4,6]]
# Out:
#             FullName  Python Marks EnrollmentDate
# 0        Alif Rahman          88.0     2024-01-15
# 1      Fatima Akhter           NaN     2024-01-20
# 2      Imran Hossain          85.0     2024-02-10
# 3   Jannatul Ferdous          82.0     2024-02-12
# 4        Kamal Uddin          95.0     2024-03-05
# 5        Laila Begum          78.0     2024-03-08
# 6     Mahmudul Hasan           NaN     2024-04-01
# 7        Nadia Islam          85.0     2024-04-22
# 8         Omar Faruq          76.0     2024-05-16
# 9       Priya Sharma          88.0     2024-05-20
# 10      Rahim Sheikh          91.0     2024-06-11
# 11   Sadia Chowdhury          87.0     2024-06-14
# 12      Tanvir Ahmed          79.0     2024-07-02
# 13        Urmi Akter           NaN     2024-07-09
# 14      Wahiduzzaman          84.0     2024-08-18
# 15      Ziaur Rahman           NaN     2024-08-21
# 16       Afsana Mimi          93.0     2025-09-01
# 17       Babul Ahmed          85.0     2025-09-05
# ...

# %%
p = df["FullName"] == "Nasir Khan"
p.idxmax()
# Out:
# 19

# %%
df.drop(1,axis=0)
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 13    PH1014        Urmi Akter                   NaN              NaN
# ...

# %%
df.drop("Location",axis=1)
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# ...

# %%
df.loc[1,"Python Marks"] = 100
df.loc[1,"CompletionStatus"] = "Completed"

df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# ...

# %%
copy = df.sort_values("Data Structure Marks")  # accending true low to high
copy
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 8     PH1009        Omar Faruq                  72.0             72.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 19    PH1020        Nasir Khan                  86.0             86.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# ...

# %%
copy = df.sort_values("Data Structure Marks", ascending=False)  # accending true high to low
copy
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 15    PH1016      Ziaur Rahman                  94.0             94.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 19    PH1020        Nasir Khan                  86.0             86.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# ...

# %%
copy = df.sort_values(["Data Structure Marks","Python Marks"], ascending=False)  # accending true high to low
copy
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 15    PH1016      Ziaur Rahman                  94.0             94.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# 19    PH1020        Nasir Khan                  86.0             86.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# ...

# %%
not_s = df.loc[df["Python Marks"] == 100]
not_s
# Out:
#   StudentID       FullName  Data Structure Marks  Algorithm Marks  \
# 1    PH1002  Fatima Akhter                  92.0             92.0
# 0       NaN            NaN                   NaN              NaN
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 1         100.0        Completed     2024-01-20  Ms. Salma  Chattogram
# 0         100.0              NaN            NaN        NaN         NaN

# %%
not_s = df.loc[df["Python Marks"] > 90]
not_s
# Out:
#    StudentID       FullName  Data Structure Marks  Algorithm Marks  \
# 1     PH1002  Fatima Akhter                  92.0             92.0
# 4     PH1005    Kamal Uddin                   NaN              NaN
# 10    PH1011   Rahim Sheikh                   NaN              NaN
# 16    PH1017    Afsana Mimi                  90.0             90.0
# 0        NaN            NaN                   NaN              NaN
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 1          100.0        Completed     2024-01-20  Ms. Salma  Chattogram
# 4           95.0      In Progress     2024-03-05  Mr. Karim  Chattogram
# 10          91.0      In Progress     2024-06-11  Mr. Karim      Khulna
# 16          93.0        Completed     2025-09-01  Mr. Karim       Dhaka
# 0          100.0              NaN            NaN        NaN         NaN

# %%
not_s = df.loc[df["Python Marks"].isna() & df["Data Structure Marks"].isna()]
not_s
# Out:
#    StudentID      FullName  Data Structure Marks  Algorithm Marks  \
# 13    PH1014    Urmi Akter                   NaN              NaN
# 18    PH1019  Faria Rahman                   NaN              NaN
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 13           NaN      Not Started     2024-07-09  Ms. Salma    Rajshahi
# 18           NaN      Not Started     2025-09-15  Mr. David  Chattogram
